# %% [markdown]
# # Multi-Omic Data Analysis
# In the first part of this notebook, we will look at putting together all of the -omics that we have seen so far: genomics, transcriptomics, and proteomics.
# <br></br>
# In the second part of this notebook, your assignment is to put this into action and demonstrate a general knowledge of the different -omics using both TCGA and CPTAC data.

# %%
import cptac
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir("C:/Users/zhang/OneDrive/college/qbio490/qbio_490_lucia/analysis_data")

# %%
#cptac.download('Brca') # shouldn't need this if already downloaded
brca = cptac.Brca()

clinical = brca.get_clinical() # Clinical Data
mutation = brca.get_somatic_mutation() # Genomic Data
rna = brca.get_transcriptomics() # Transcriptomic Data
protein = brca.get_proteomics() # Proteomic Data
protein.columns = protein.columns.get_level_values(0) # Fix protein data columns

# %%
protein = brca.get_proteomics() # Proteomic Data
protein.columns = protein.columns.get_level_values(0)

# %% [markdown]
# ## Let's revisit the structure of our different -omics...
# ### Clinical

# %% [markdown]
# This is the data about the patient that was collected at the time that the sample was taken.
# Rows are patients, columns are variables.

# %%
clinical.head()
# Out:
# Name       Replicate_Measurement_IDs Sample_Tumor_Normal TMT.Plex TMT.Channel  \
# Patient_ID
# CPT000814                  CPT000814               Tumor       13        127C
# CPT001846                  CPT001846               Tumor       12        128C
# X01BR001                    X01BR001               Tumor        2        129N
# X01BR008                    X01BR008               Tumor       16        127C
# X01BR009                    X01BR009               Tumor       16        127N
#
# Name            Stage  Ischemia.Time.in.Minutes  PAM50 NMF.Cluster  \
# Patient_ID
# CPT000814   Stage IIA                       NaN  Basal     Basal-I
# CPT001846   Stage III                       NaN  Basal     Basal-I
# X01BR001    Stage IIB                       0.0  Basal     Basal-I
# X01BR008          NaN                       NaN  Basal     Basal-I
# X01BR009          NaN                       NaN  Basal     Basal-I
#
# Name        NMF.Cluster.Membership.Score  Age.in.Month  Gender  \
# Patient_ID
# CPT000814                          1.000           NaN     NaN
# CPT001846                          0.672           NaN     NaN
# X01BR001                           0.782         660.0  female
# X01BR008                           0.958           NaN     NaN
# X01BR009                           0.825           NaN     NaN
#
# Name                        Ethnicity ER.Updated.Clinical.Status  \
# Patient_ID
# CPT000814   black.or.african.american                   negative
# CPT001846                       white                   negative
# X01BR001    black.or.african.american                   negative
# X01BR008                          NaN                        NaN
# X01BR009                          NaN                   negative
#
# Name       PR.Clinical.Status ERBB2.Updated.Clinical.Status  \
# Patient_ID
# CPT000814            negative                           NaN
# CPT001846            negative                           NaN
# X01BR001             negative                      negative
# X01BR008                  NaN                           NaN
# X01BR009             negative                           NaN
#
# Name       TNBC.Updated.Clinical.Status ERBB2.Proteogenomic.Status  \
# Patient_ID
# CPT000814                      positive                   negative
# CPT001846                      positive                   negative
# X01BR001                       positive                   negative
# X01BR008                            NaN                   negative
# X01BR009                       positive                   negative
#
# Name       TOP2A.Proteogenomic.Status
# Patient_ID
# CPT000814                    negative
# CPT001846                    negative
# X01BR001                     negative
# X01BR008                     negative
# X01BR009                     negative

# %% [markdown]
# ### Mutation
# Our mutation data looks a little different than it did as a MAF file, but the important information is still here. Rows are patients, Gene is the name of the gene, Mutation is the type of mutation, and Location is where the mutation occurs.

# %%
mutation.head()
# Out:
# Name           Gene           Mutation      Location
# Patient_ID
# CPT000814     ABCG8  Missense_Mutation       p.V660L
# CPT000814    ACTRT1  Missense_Mutation       p.S138F
# CPT000814       ADA  Missense_Mutation        p.A73T
# CPT000814    AHCTF1    Frame_Shift_Del  p.I1012Sfs*9
# CPT000814   ANGPTL4             Silent       p.C341C

# %% [markdown]
# ### RNA and Protein
# These both look exactly the same. The rows are patients, columns are genes, and the numbers represent log2 fold change compared to the standard. Note that the RNA DataFrame has roughly 2x as many columns as the Protein DataFrame. This is because of non-coding genes.

# %%
rna.head()
# Out:
# Name          A1BG  A1BG-AS1  A1CF     A2M   A2ML1   A2MP1  A3GALT2  A4GALT  \
# Patient_ID
# CPT000814   1.9265    2.4267   NaN  5.3718  3.6437 -4.5301  -5.2608  0.6260
# CPT001846   3.6578    2.6524   NaN  5.3253 -5.1069 -0.7692   5.6915  3.2060
# X01BR001    0.9896    2.6363   NaN  5.4734 -1.5052 -2.0918      NaN  1.8816
# X01BR008    0.5535    2.2119   NaN  5.8701  3.2708 -1.9902  -5.0414  0.6957
# X01BR009    2.8359    3.3449   NaN  6.9307  2.6488 -3.1664      NaN  1.9784
#
# Name         A4GNT    AAAS  ...  ZWILCH   ZWINT    ZXDA    ZXDB    ZXDC  \
# Patient_ID                  ...
# CPT000814      NaN  4.7000  ...  3.2268  5.1482 -0.0202  0.9270  5.1699
# CPT001846      NaN  4.3115  ...  3.2532  3.9191 -1.4924 -0.3262  3.2163
# X01BR001       NaN  3.3434  ...  1.9491  2.2365  0.1694  1.3074  2.8806
# X01BR008       NaN  4.3095  ...  3.1575  5.7822 -1.3608  0.3015  3.2620
# X01BR009   -5.7975  4.6341  ...  2.7678  3.5378 -0.5147  0.2798  3.0986
#
# Name        ZYG11A  ZYG11B     ZYX   ZZEF1    ZZZ3
# Patient_ID
# CPT000814   3.1333  0.9835  5.9499  2.8499  3.6497
# CPT001846      NaN  2.0909  7.0671  2.0780  3.2274
# X01BR001    0.5653  1.5682  4.3852  2.1573  2.1127
# X01BR008    1.7578  0.2989  5.4697  3.1783  3.1939
# X01BR009   -3.2737  1.3036  5.0219  3.6868  2.8524
#
# [5 rows x 23121 columns]

# %%
protein.head()
# Out:
# Name          A1BG     A2M   A2ML1    AAAS    AACS   AADAT   AAED1   AAGAB  \
# Patient_ID
# CPT000814  -0.6712 -0.2075  2.7959  1.3969 -1.0899     NaN  1.6708 -0.3484
# CPT001846   1.3964  1.3302 -5.0948  0.7674 -1.6845     NaN  2.1022 -0.5814
# X01BR001    2.0219  1.6269 -3.2943  0.3352 -1.0739  1.2255  0.2754 -1.1187
# X01BR008   -0.5290  0.3267  1.4342  0.4938 -2.8676     NaN     NaN -1.0691
# X01BR009    1.2556  3.4489  2.8043 -0.2956 -1.7261     NaN     NaN -2.0471
#
# Name          AAK1   AAMDC  ...  ZSCAN31  ZSWIM8    ZW10  ZWILCH   ZWINT  \
# Patient_ID                  ...
# CPT000814  -0.4756 -0.7299  ...  -5.2868 -0.6536  0.3384  2.1169  1.3910
# CPT001846   0.2916 -2.2857  ...  -0.7592  0.4711  0.6018  0.2062 -0.2137
# X01BR001   -0.0534 -0.2519  ...      NaN  0.2306 -0.3010  0.3395 -0.5316
# X01BR008   -0.3643 -1.8173  ...  -2.1789  0.2695  0.1506  1.0498  0.7546
# X01BR009   -0.3547 -0.8298  ...  -2.3990 -0.2596  0.1898 -0.5010 -0.4189
#
# Name          ZXDC  ZYG11B     ZYX   ZZEF1    ZZZ3
# Patient_ID
# CPT000814  -2.1230  0.9136 -0.8082 -1.4793  0.9136
# CPT001846  -2.1219  0.0860  2.5814 -0.2852 -0.1074
# X01BR001       NaN  0.4996  0.7622 -1.5607  0.0256
# X01BR008    1.7889 -0.2499 -0.2590 -0.1263  0.3725
# X01BR009    0.3080  0.5057  0.2181 -0.2288 -0.2750
#
# [5 rows x 10107 columns]

# %% [markdown]
# ## Reformatting data
# ### Finding shared patients
# All 4 DataFrames we have here share the common characteristic that the rows are the patient_IDs. This is actually really helpful! However, not all DataFrames have the same number of patients. For example, the mutation DataFrame has many times more rows than patients because each patient shows up everytime for a new mutation. Othertimes, you have masked out some patients from a DataFrame but not the other. In order to find the shared patients between DataFrames, we can use the np.intersect1d() function.

# %%
# skeleton code

patients_df1 = df1.index # the indices of each DF are the patients within that DF
patients_df2 = df2.index

shared_patients = np.intersect1d(patients_df1, patients_df2) # find shared and save indices

shared_df1 = df1.loc[shared_patients, :] # use our list of shared patients to grab only those patients
shared_df2 = df2.loc[shared_patients, :] # notice we are grabbing all columns and assigning to new df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # skeleton code
# ----> 3 patients_df1 = df1.index # the indices of each DF are the patients within that DF
#       4 patients_df2 = df2.index
#       6 shared_patients = np.intersect1d(patients_df1, patients_df2) # find shared and save indices
#
# NameError: name 'df1' is not defined

# %% [markdown]
# Example

# %%
high_MUC16_prot = protein[protein.loc[:, 'MUC16'] > 1]
high_MUC16_RNA = rna[rna.loc[:, 'MUC16'] > 1]

shared_MUC16 = np.intersect1d(high_MUC16_prot.index, high_MUC16_RNA.index)

print(f'prot rows: {len(high_MUC16_prot)}')
print(f'RNA rows: {len(high_MUC16_RNA)}')
print(f'shared patients: {len(shared_MUC16)}')
# Out:
# prot rows: 27
# RNA rows: 32
# shared patients: 13

# %% [markdown]
# ### Counting # of Somatic Mutations in Individual
# Say we wanted to look at how the number of mutations in MUC16 relate to RNA and protein expression. How do we do this? We can't use the prior approach since the Mutation DF has many more rows than # of patients. We want to get a count of the number of MUC16 mutations in each patient. We can use the  Series.value_counts() method.

# %%
# Start by getting only mutations you are interested in
MUC16_mutat_mask = mutation.loc[:, 'Gene'] == 'MUC16'
MUC16_mutations = mutation.loc[MUC16_mutat_mask, :]
MUC16_mutations.head()
# Out:
# Name         Gene           Mutation   Location
# Patient_ID
# CPT001846   MUC16  Missense_Mutation   p.K3653Q
# X01BR023    MUC16  Missense_Mutation  p.T13038A
# X01BR026    MUC16             Silent  p.G13669G
# X01BR026    MUC16             Silent  p.V13666V
# X01BR043    MUC16  Missense_Mutation  p.R14400Q

# %%
# Then get a list of the patient names (hint: the index)
patients_with_mutation = MUC16_mutations.index

# Then use the value_counts() function to count how many times each patient appears
MUC16_counts = patients_with_mutation.value_counts()
print(MUC16_counts)
# Out:
# X01BR043     30
# X01BR026      2
# X20BR006      2
# X18BR003      2
# CPT001846     1
# X11BR050      1
# X18BR007      1
# X14BR005      1
# X11BR080      1
# X11BR060      1
# X11BR010      1
# X11BR031      1
# X01BR023      1
# X11BR006      1
# X11BR003      1
# X09BR007      1
# X09BR004      1
# X06BR003      1
# X20BR007      1
# Name: Patient_ID, dtype: int64

# %% [markdown]
# Wow it looks like one patient, X01BR043, has the majority of all MUC16 mutations. Let's see what fraction of our MUC16 patients are in our shared high MUC16 RNA and Protein list from before

# %%
np.intersect1d(MUC16_counts.index, shared_MUC16)
# Out:
# array(['X09BR004', 'X09BR007'], dtype=object)

# %% [markdown]
# Only two patients were shared between the list. Perhaps this means that the converse is true.. that mutations are linked to lower gene expression. Let's put all of this data together for our analysis.

# %%
patients_df = pd.DataFrame(
    columns=['MUC16_Mutations', 'RNA_Expression', 'Protein_Expression'], 
    index=clinical.index)

patients_df
# Out:
#            MUC16_Mutations RNA_Expression Protein_Expression
# Patient_ID
# CPT000814              NaN            NaN                NaN
# CPT001846              NaN            NaN                NaN
# X01BR001               NaN            NaN                NaN
# X01BR008               NaN            NaN                NaN
# X01BR009               NaN            NaN                NaN
# ...                    ...            ...                ...
# X21BR001               NaN            NaN                NaN
# X21BR002               NaN            NaN                NaN
# X21BR010               NaN            NaN                NaN
# X22BR005               NaN            NaN                NaN
# X22BR006               NaN            NaN                NaN
#
# [122 rows x 3 columns]

# %% [markdown]
# Now that we have our DataFrame, let's fill in the values.

# %%
patients_df.loc[MUC16_counts.index, 'MUC16_Mutations'] = MUC16_counts
patients_df.loc[patients_df.index.difference(MUC16_counts.index), 'MUC16_Mutations'] = 0
# df.index.difference(list) gives you all of the indices for the rows that are not in that list
# here, we are setting all of the patients who don't appear in MUC16_Mutations to have 0 mutations

patients_df.loc[:, 'RNA_Expression'] = rna.loc[:, 'MUC16']
patients_df.loc[:, 'Protein_Expression'] = protein.loc[:, 'MUC16']

# %%
print(patients_df.isna().sum()) # count number of NAs in each column, let's drop the rows with NAs
patients_df.dropna(axis=0, inplace=True) # drops rows with NA values, alternatively use axis=1 to drop columns
# Out:
# MUC16_Mutations       0
# RNA_Expression        3
# Protein_Expression    6
# dtype: int64

# %% [markdown]
# Let's see if we can gain anything from a UMAP of our data...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from umap import UMAP
import matplotlib.patches as mpatches
import matplotlib.lines as lines

reducer = UMAP()
transformed_df = scaler.fit_transform(patients_df)
embedding = reducer.fit_transform(transformed_df)

colors_rna = np.where(patients_df.loc[:, 'RNA_Expression'] > 1, 'blue', 'grey')
colors_protein = np.where(patients_df.loc[:, 'Protein_Expression'] > 1, 'red', 'grey')
show_mutations = np.where(patients_df.loc[:, 'MUC16_Mutations'] > 0, 0.3, 0)

fig, ax = plt.subplots()

ax.scatter(embedding[:, 0], embedding[:, 1], c=colors_rna, s=20, alpha=0.6)
ax.scatter(embedding[:, 0], embedding[:, 1], c=colors_protein, s=20, alpha=0.5)
ax.scatter(embedding[:, 0], embedding[:, 1], alpha=show_mutations, color='white', s=100, edgecolor='Black')

rna = mpatches.Patch(color='blue', label='High MUC16 RNA')
protein = mpatches.Patch(color='red', label='High MUC16 Protein')
shared = mpatches.Patch(color='mediumorchid', label='High MUC16 RNA+Protein')
mutations = lines.Line2D([], [], color="white", alpha=0.5, marker='o', markersize=10, markerfacecolor="white", markeredgecolor='black', label='MUC16 Mutation +')

ax.legend(handles=[rna, protein, shared, mutations], bbox_to_anchor=[0.85,-0.05], fancybox=True, ncol=2)

# %% [markdown]
# From our plot, we can see that while the Mutation+ patients tend to be spread throughout the different categories, it doesn't seem like many are high in both MUC16 RNA expression AND MUC16 Protein expression.

# %% [markdown]
# ## Assignment
# This assignment has 2 parts and unlike the past few assignments, it will be more open-ended. Grading will be based on effort and thoughtful analysis, not whether your data was significant.

# %% [markdown]
# **Exercise 1** - Investigate the Central Dogma (5pt)
# <br>
# Complete a multi-omic analysis analysis of a gene, looking at how mutation rate, RNA expression, and protein expression are correlated (or not!). Choose your gene logically and include a justification (e.g. relative protein abundance, high nonsense mutation rate, based in the literature as having implications with breast cancer, etc).
# You may not use any of the following genes: TP53, TTN, PIK3CA, MUC16, BRCA1/2.
# <br> </br>
# Include the following (1pt each):
# + Justification for choosing the gene (e.g. relevant code used to pick or link to research article). One to two sentence explanation of the function of the gene.
# + Examination of the somatic mutations with respect to type, number per individual, or density
# + Some form of figure that shows relationship between RNA expression and Protein Expression
# + A statistical test that gives a p-value. Interpret the p-value in terms of the test and the data. We've mostly looked at correlation tests but you don't necessarily have to use one. Scipy.stats is a great resource https://docs.scipy.org/doc/scipy/reference/stats.html#correlation-functions
# + Three to four sentence writeup of your thoughts behind why you got the results you got (just brainstorm some ideas, it doesn't need to be super thorough)
#
# Remember: If there is no correlation, state that, you don't need to try multiple genes if you aren't getting promising results.

# %% [markdown]
# I looked at this paper (https://genomemedicine.biomedcentral.com/articles/10.1186/s13073-015-0228-1) and saw that they mentioned VWDE as none of the top driver oncogenes having a mutation prevalence over 5%. I also looked at the mutation dataframe and saw that the VWDE gene had quote a few mutations

# %%
VWDE_mutations = mutation[mutation['Gene'] == 'VWDE']
VWDE_mutations
# Out:
# Name        Gene           Mutation  Location
# Patient_ID
# X01BR043    VWDE  Missense_Mutation  p.S1435L
# X01BR043    VWDE             Silent  p.T1356T
# X01BR043    VWDE  Missense_Mutation  p.P1350S
# X01BR043    VWDE  Missense_Mutation  p.E1216K
# X01BR043    VWDE             Silent   p.L704L
# X01BR043    VWDE  Missense_Mutation   p.G566E
# X01BR043    VWDE             Silent   p.N392N
# X05BR044    VWDE  Missense_Mutation  p.M1004V
# X11BR017    VWDE  Missense_Mutation   p.H684R
# X11BR075    VWDE  Missense_Mutation    p.S98L
# X18BR007    VWDE  Missense_Mutation   p.S799C

# %%
# Examine somatic mutations, the number of high expressions, and which patients faced both.
mutation.head()
high_VWDE_prot = protein[protein.loc[:, 'VWDE'] > 1]
high_VWDE_RNA = rna[rna.loc[:, 'VWDE'] > 1]

shared_VWDE = np.intersect1d(high_VWDE_prot.index, high_VWDE_RNA.index)

print(f'high protein rows: {len(high_VWDE_prot)}')
print(f'high RNA rows: {len(high_VWDE_RNA)}')
print(f'number of shared patients: {len(shared_VWDE)}')
# Out:
# high protein rows: 11
# high RNA rows: 27
# number of shared patients: 1

# %%
patients = VWDE_mutations.index
VWDE_counts = patients_with_mutation.value_counts()
print(VWDE_counts)
# Out:
# X01BR043     30
# X01BR026      2
# X20BR006      2
# X18BR003      2
# CPT001846     1
# X11BR050      1
# X18BR007      1
# X14BR005      1
# X11BR080      1
# X11BR060      1
# X11BR010      1
# X11BR031      1
# X01BR023      1
# X11BR006      1
# X11BR003      1
# X09BR007      1
# X09BR004      1
# X06BR003      1
# X20BR007      1
# Name: Patient_ID, dtype: int64

# %%
VWDE_rna= rna[['VWDE']]
VWDE_protein = protein[['VWDE']]
VWDE_rna.reset_index(inplace=True)
VWDE_protein.reset_index(inplace=True)

# %%
VWDE_merge = pd.merge(VWDE_rna, VWDE_protein, left_on='Patient_ID', right_on="Patient_ID")
VWDE_merge = VWDE_merge.dropna()

# %%
# Show relationship between RNA expression and protein expression
VWDE_merge.columns = ['Patient_ID', 'rna', 'protein']
plt.scatter(VWDE_merge['rna'], VWDE_merge['protein'])
plt.xlabel("RNA Expression")
plt.ylabel("Protein Expression")
# Out:
# Text(0, 0.5, 'Protein Expression')

# %%
# Print p-value for correlation between the RNA expression and protein expression
from scipy.stats import pearsonr
pearsonr(VWDE_merge['rna'], VWDE_merge['protein'])
# Out:
# PearsonRResult(statistic=-0.11704117310867099, pvalue=0.4902727136021824)

# %% [markdown]
# It wasn't significant, but it looked like higher RNA expression was correlated lower protein expression. I wasn't quite sure why -- perhaps it had to do with the modifications the cells make to RNA after it's be transcribed. It's probably more likely that there isn't a direct causation. Instead, there's a correlation due to other genes or other aspects of the cell.

# %% [markdown]
# **Exercise 2** - Looking for Connections (5pt)
# As the types or size of data increases, it can be harder to find patterns within the data. This presents a perfect opportunity to use one of our newest techniques: machine learning. In this exercise, you will attempt to predict a clinical variable based on genetic and mutation data.
# <br></br>
# Our clinical data from CPTAC is pretty sparse however, and doesn't give us much in the way to predict. Luckily, we can use our TCGA data just as easily. Using the pd.read_csv() functions, read in your clinical, mutation, and transcriptomic data.
# <br></br>
# Your task is as follows (1pt each):
# + Load in your TCGA analysis_data and choose one of the following clinical variables:
#  vital_status, days_to_last_known_alive/days_to_death/days_to_last_followup (combine), histological_type, age_at_initial_pathologic_diagnosis, lymph_node_examined_count or breast_carcinoma_progesterone_receptor_status.
# + Determine which genes you want to use for your regressor/classifier (you can use ones we've looked at, genes which are commonly associated with breast cancer outcomes, the most mutated genes, etc) and create a DataFrame that includes those genes RNA and mutation data. You can choose which data/how many data dimensions you want.
# + Train a regressor/classifier (your choice of which method) on your chosen data with the target being your chosen variable (hint: if you choose a categorical variable, you will need to use a LabelEncoder())
# + Measure and interpret the accuracy of the model. If you do not get above a 0.5 accuracy (for classification) or within 10% of the target (regression), retry with a different ML model, train test split, or genes used. If you cannot meet any of the goals within 5 tries, move on (it's okay!).
# + Write a few sentences about why a machine learning algorithm like a regressor/classifier would be important in a clinical setting. Depending on whether you got it within 5 tries or not, discuss why you think your genes/parameters were/were not able to predict it.

# %%
# write code here
rna_clinical = pd.read_csv("brca_rna_clinical_data.csv")
clinical = pd.read_csv("brca_clinical_data.csv")
count = pd.read_csv("brca_rna_count_data.csv")
gene = pd.read_csv("brca_rna_gene_data.csv")
mutation = pd.read_csv('brca_rna_mutation_data.csv')

# %%
count.head()
# Out:
#            Unnamed: 0  TCGA-LL-A73Y-01A-11R-A33J-07  \
# 0  ENSG00000000003.15                          7015
# 1   ENSG00000000005.6                            16
# 2  ENSG00000000419.13                          2167
# 3  ENSG00000000457.14                          2505
# 4  ENSG00000000460.17                           726
#
#    TCGA-E2-A1IU-01A-11R-A14D-07  TCGA-AO-A03U-01B-21R-A10J-07  \
# 0                           850                          7104
# 1                             5                             2
# 2                          1680                          1937
# 3                          1559                          1073
# 4                           402                           295
#
#    TCGA-E9-A1NH-01A-11R-A14D-07  TCGA-BH-A1EY-01A-11R-A13Q-07  \
# 0                          3590                          1680
# 1                            18                            22
# 2                          1460                          1497
# 3                          2006                          1364
# 4                           568                           276
#
#    TCGA-AO-A1KS-01A-11R-A13Q-07  TCGA-B6-A0I6-01A-11R-A034-07  \
# 0                          5758                          2501
# 1                            33                             0
# 2                          2520                          2054
# 3                          2238                           557
# 4                          1198                           350
#
#    TCGA-E9-A229-01A-31R-A157-07  TCGA-D8-A27H-01A-11R-A16F-07  ...  \
# 0                          3652                          3015  ...
# 1                             5                             4  ...
# 2                          3277                          2815  ...
# 3                          1577                          1318  ...
# 4                           700                           738  ...
#
#    TCGA-AR-A2LJ-01A-12R-A19W-07  TCGA-AO-A12H-01A-11R-A115-07  \
# 0                          2100                          3957
# 1                            95                             3
# 2                          1331                          1802
# 3                           701                          1032
# 4                           371                           263
#
#    TCGA-E2-A155-01A-11R-A12D-07  TCGA-BH-A0BW-01A-11R-A115-07  \
# 0                          3148                          3211
# 1                            12                             1
# 2                          2303                          2144
# 3                          1860                          1707
# 4                           637                           522
#
#    TCGA-B6-A0X1-01A-11R-A109-07  TCGA-AC-A3OD-01B-06R-A22O-07  \
# 0                          1053                           519
# 1                             1                            11
# 2                          1449                           368
# 3                           618                           734
# 4                           597                           313
#
#    TCGA-AC-A6IX-01A-12R-A32P-07  TCGA-E9-A1RB-01A-11R-A157-07  \
# 0                          4024                          2364
# 1                           414                             4
# 2                          1813                          4439
# 3                          1863                          2278
# 4                           552                          2145
#
#    TCGA-A8-A07Z-01A-11R-A00Z-07  TCGA-A2-A0EY-01A-11R-A034-07
# 0                          2343                          1954
# 1                             2                            16
# 2                          1699                          2123
# 3                          1092                          1802
# 4                           664                           694
#
# [5 rows x 1119 columns]

# %%
gene.head()
# Out:
#    source  type  score  phase             gene_id       gene_type gene_name  \
# 0  HAVANA  gene    NaN    NaN  ENSG00000000003.15  protein_coding    TSPAN6
# 1  HAVANA  gene    NaN    NaN   ENSG00000000005.6  protein_coding      TNMD
# 2  HAVANA  gene    NaN    NaN  ENSG00000000419.13  protein_coding      DPM1
# 3  HAVANA  gene    NaN    NaN  ENSG00000000457.14  protein_coding     SCYL3
# 4  HAVANA  gene    NaN    NaN  ENSG00000000460.17  protein_coding  C1orf112
#
#    level     hgnc_id           havana_gene
# 0      2  HGNC:11858  OTTHUMG00000022002.2
# 1      2  HGNC:17757  OTTHUMG00000022001.2
# 2      2   HGNC:3005  OTTHUMG00000032742.2
# 3      2  HGNC:19285  OTTHUMG00000035941.6
# 4      2  HGNC:25565  OTTHUMG00000035821.9

# %%
count.columns
# Out:
# Index(['Unnamed: 0', 'TCGA-LL-A73Y-01A-11R-A33J-07',
#        'TCGA-E2-A1IU-01A-11R-A14D-07', 'TCGA-AO-A03U-01B-21R-A10J-07',
#        'TCGA-E9-A1NH-01A-11R-A14D-07', 'TCGA-BH-A1EY-01A-11R-A13Q-07',
#        'TCGA-AO-A1KS-01A-11R-A13Q-07', 'TCGA-B6-A0I6-01A-11R-A034-07',
#        'TCGA-E9-A229-01A-31R-A157-07', 'TCGA-D8-A27H-01A-11R-A16F-07',
#        ...
#        'TCGA-AR-A2LJ-01A-12R-A19W-07', 'TCGA-AO-A12H-01A-11R-A115-07',
#        'TCGA-E2-A155-01A-11R-A12D-07', 'TCGA-BH-A0BW-01A-11R-A115-07',
#        'TCGA-B6-A0X1-01A-11R-A109-07', 'TCGA-AC-A3OD-01B-06R-A22O-07',
#        'TCGA-AC-A6IX-01A-12R-A32P-07', 'TCGA-E9-A1RB-01A-11R-A157-07',
#        'TCGA-A8-A07Z-01A-11R-A00Z-07', 'TCGA-A2-A0EY-01A-11R-A034-07'],
#       dtype='object', length=1119)

# %%
mutation.head()
# Out:
#    X1 Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 0  1   NMNAT1      64802           WUGSC  GRCh38     chr1
# 1  1   MTOR        2475            WUGSC  GRCh38     chr1
# 2  1   INPP5B      3633            WUGSC  GRCh38     chr1
# 3  1   HIVEP3      59269           WUGSC  GRCh38     chr1
# 4  1   ATP6V0B     533             WUGSC  GRCh38     chr1
#
#    Start_Position  End_Position Strand Variant_Classification Variant_Type  \
# 0  9972183         9972183       +      Missense_Mutation      SNP
# 1  11114872        11114872      +      Missense_Mutation      SNP
# 2  37873085        37873085      +      Missense_Mutation      SNP
# 3  41513234        41513234      +      Missense_Mutation      SNP
# 4  43976100        43976100      +      Missense_Mutation      SNP
#
#   Reference_Allele Tumor_Seq_Allele1 Tumor_Seq_Allele2      dbSNP_RS  \
# 0  G                G                 T                 NaN
# 1  C                C                 G                 NaN
# 2  C                C                 T                 NaN
# 3  C                C                 T                 rs767289271
# 4  G                G                 C                 rs1421053767
#
#    dbSNP_Val_Status Tumor_Sample_Barcode   Matched_Norm_Sample_Barcode  \
# 0 NaN                TCGA-LL-A73Y         TCGA-LL-A73Y-10B-01D-A33H-09
# 1 NaN                TCGA-LL-A73Y         TCGA-LL-A73Y-10B-01D-A33H-09
# 2 NaN                TCGA-LL-A73Y         TCGA-LL-A73Y-10B-01D-A33H-09
# 3 NaN                TCGA-LL-A73Y         TCGA-LL-A73Y-10B-01D-A33H-09
# 4 NaN                TCGA-LL-A73Y         TCGA-LL-A73Y-10B-01D-A33H-09
#
#    Match_Norm_Seq_Allele1  Match_Norm_Seq_Allele2  Tumor_Validation_Allele1  \
# 0 NaN                     NaN                     NaN
# 1 NaN                     NaN                     NaN
# 2 NaN                     NaN                     NaN
# 3 NaN                     NaN                     NaN
# 4 NaN                     NaN                     NaN
#
#    Tumor_Validation_Allele2  Match_Norm_Validation_Allele1  \
# 0 NaN                       NaN
# 1 NaN                       NaN
# 2 NaN                       NaN
# 3 NaN                       NaN
# 4 NaN                       NaN
#
#    Match_Norm_Validation_Allele2  Verification_Status  Validation_Status  \
# 0 NaN                            NaN                  NaN
# 1 NaN                            NaN                  NaN
# 2 NaN                            NaN                  NaN
# 3 NaN                            NaN                  NaN
# 4 NaN                            NaN                  NaN
#
#   Mutation_Status  Sequencing_Phase  Sequence_Source  Validation_Method  \
# 0  Somatic        NaN               NaN              NaN
# 1  Somatic        NaN               NaN              NaN
# 2  Somatic        NaN               NaN              NaN
# 3  Somatic        NaN               NaN              NaN
# 4  Somatic        NaN               NaN              NaN
#
#    Score  BAM_File  Sequencer                     Tumor_Sample_UUID  \
# 0 NaN    NaN       NaN         ac077103-6e1b-423f-bf85-4ba798e08ce2
# 1 NaN    NaN       NaN         ac077103-6e1b-423f-bf85-4ba798e08ce2
# 2 NaN    NaN       NaN         ac077103-6e1b-423f-bf85-4ba798e08ce2
# 3 NaN    NaN       NaN         ac077103-6e1b-423f-bf85-4ba798e08ce2
# 4 NaN    NaN       NaN         ac077103-6e1b-423f-bf85-4ba798e08ce2
#
#                Matched_Norm_Sample_UUID      HGVSc         HGVSp HGVSp_Short  \
# 0  5f044f10-3304-4071-8d16-906af45517dd  c.110G>T   p.Gly37Val    p.G37V
# 1  5f044f10-3304-4071-8d16-906af45517dd  c.7105G>C  p.Glu2369Gln  p.E2369Q
# 2  5f044f10-3304-4071-8d16-906af45517dd  c.2272G>A  p.Glu758Lys   p.E758K
# 3  5f044f10-3304-4071-8d16-906af45517dd  c.5987G>A  p.Arg1996Gln  p.R1996Q
# 4  5f044f10-3304-4071-8d16-906af45517dd  c.127G>C   p.Glu43Gln    p.E43Q
#
#      Transcript_ID Exon_Number  t_depth  t_ref_count  t_alt_count  n_depth  \
# 0  ENST00000377205  2/5         91       83           8            46
# 1  ENST00000361445  52/58       92       45           47           55
# 2  ENST00000373023  19/24       140      68           71           72
# 3  ENST00000372583  8/9         54       25           29           21
# 4  ENST00000472174  3/8         65       37           27           28
#
#    n_ref_count  n_alt_count  \
# 0 NaN          NaN
# 1 NaN          NaN
# 2 NaN          NaN
# 3 NaN          NaN
# 4 NaN          NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      all_effects  \
# 0  NMNAT1,missense_variant,p.G37V,ENST00000377205,NM_001297778.1&NM_022787.4,c.110G>T,MODERATE,YES,tolerated(0.22),benign(0.345),1;NMNAT1,missense_variant,p.G37V,ENST00000403197,NM_001297779.2,c.110G>T,MODERATE,,tolerated(0.19),benign(0.063),1;MIR5697,downstream_gene_variant,,ENST00000578045,,,MODIFIER,YES,,,1;NMNAT1,non_coding_transcript_exon_variant,,ENST00000492735,,n.194G>T,MODIFIER,,,,1;NMNAT1,missense_variant,p.G37V,ENST00000462686,,c.110G>T,MODERATE,,tolerated(0.22),benign(0.345),1
# 1  MTOR,missense_variant,p.E2369Q,ENST00000361445,NM_004958.4,c.7105G>C,MODERATE,YES,deleterious(0),probably_damaging(0.993),-1;MTOR,missense_variant,p.E574Q,ENST00000376838,,c.1720G>C,MODERATE,,deleterious(0),probably_damaging(0.993),-1;MTOR,missense_variant,p.E25Q,ENST00000455339,,c.73G>C,MODERATE,,deleterious(0),probably_damaging(0.993),-1;MTOR,non_coding_transcript_exon_variant,,ENST00000490931,,n.148G>C,MODIFIER,,,,-1;MTOR,upstream_gene_variant,,ENST00000473471,,,MODIFIER,,,,-1
# 2  INPP5B,missense_variant,p.E758K,ENST00000373023,,c.2272G>A,MODERATE,YES,deleterious(0.02),probably_damaging(0.997),-1;INPP5B,missense_variant,p.E678K,ENST00000373024,NM_001365821.1&NM_005540.3&NM_001365822.1&NM_001365820.1,c.2032G>A,MODERATE,,deleterious(0.04),probably_damaging(0.999),-1;INPP5B,missense_variant,p.E678K,ENST00000458109,,c.2032G>A,MODERATE,,deleterious(0.04),probably_damaging(0.984),-1;INPP5B,missense_variant,p.E514K,ENST00000373027,NM_001365825.1&NM_001365823.1&NM_001365824.1&NM_001350228.1&NM_001350227.2&NM_001297434.2,c.1540G>A,MODERATE,,deleterious(0.03),probably_damaging(0.997),-1;INPP5B,missense_variant,p.E758K,ENST00000373026,,c.2272G>A,MODERATE,,deleterious(0.02),probably_damaging(0.997),-1;INPP5B,non_coding_transcript_exon_variant,,ENST00000474758,,n.303G>A,MODIFIER,,,,-1;INPP5B,upstream_gene_variant,,ENST00000470364,,,MODIFIER,,,,-1
# 3  HIVEP3,missense_variant,p.R1996Q,ENST00000372583,NM_024503.5,c.5987G>A,MODERATE,YES,tolerated(0.2),benign(0.003),-1;HIVEP3,missense_variant,p.R1996Q,ENST00000372584,NM_001127714.3,c.5987G>A,MODERATE,,tolerated(0.2),benign(0.007),-1;HIVEP3,missense_variant,p.R1996Q,ENST00000643665,,c.5987G>A,MODERATE,,tolerated(0.2),benign(0.007),-1;HIVEP3,non_coding_transcript_exon_variant,,ENST00000460604,,n.914G>A,MODIFIER,,,,-1
# 4  ATP6V0B,missense_variant,p.E43Q,ENST00000532642,NM_001294333.2,c.127G>C,MODERATE,YES,tolerated(0.16),benign(0.053),1;ATP6V0B,missense_variant,p.E43Q,ENST00000472174,NM_004047.5,c.127G>C,MODERATE,,tolerated(0.32),benign(0.017),1;ATP6V0B,missense_variant,p.E90Q,ENST00000471859,,c.268G>C,MODERATE,,tolerated(0.11),benign(0.402),
#
#   Allele             Gene          Feature Feature_type   One_Consequence  \
# 0  T      ENSG00000173614  ENST00000377205  Transcript   missense_variant
# 1  G      ENSG00000198793  ENST00000361445  Transcript   missense_variant
# 2  T      ENSG00000204084  ENST00000373023  Transcript   missense_variant
# 3  T      ENSG00000127124  ENST00000372583  Transcript   missense_variant
# 4  C      ENSG00000117410  ENST00000472174  Transcript   missense_variant
#
#         Consequence cDNA_position CDS_position Protein_position Amino_acids  \
# 0  missense_variant  207/3734      110/840      37/279           G/V
# 1  missense_variant  7226/8721     7105/7650    2369/2549        E/Q
# 2  missense_variant  2366/4694     2272/2982    758/993          E/K
# 3  missense_variant  7297/12617    5987/7221    1996/2406        R/Q
# 4  missense_variant  208/987       127/618      43/205           E/Q
#
#     Codons          Existing_variation  DISTANCE  TRANSCRIPT_STRAND   SYMBOL  \
# 0  gGa/gTa  COSV101020467              NaN        1                  NMNAT1
# 1  Gag/Cag  COSV100816737;COSV63867942 NaN       -1                  MTOR
# 2  Gag/Aag  COSV100886643              NaN       -1                  INPP5B
# 3  cGa/cAa  rs767289271;COSV99914150   NaN       -1                  HIVEP3
# 4  Gag/Cag  rs1421053767;COSV99356680  NaN        1                  ATP6V0B
#
#   SYMBOL_SOURCE     HGNC_ID         BIOTYPE CANONICAL       CCDS  \
# 0  HGNC          HGNC:17877  protein_coding  YES       CCDS108.1
# 1  HGNC          HGNC:3942   protein_coding  YES       CCDS127.1
# 2  HGNC          HGNC:6077   protein_coding  YES       NaN
# 3  HGNC          HGNC:13561  protein_coding  YES       CCDS463.1
# 4  HGNC          HGNC:861    protein_coding  NaN       CCDS505.1
#
#               ENSP   SWISSPROT         TREMBL        UNIPARC UNIPROT_ISOFORM  \
# 0  ENSP00000366410  Q9HAN9.172  A0A024R4E1.41  UPI0000041261  NaN
# 1  ENSP00000354558  P42345.215  NaN            UPI000012ABD3  NaN
# 2  ENSP00000362114  P32019.180  NaN            UPI0000458AD6  P32019-1
# 3  ENSP00000361664  Q5T1R4.146  NaN            UPI000013CC24  Q5T1R4-1
# 4  ENSP00000431605  Q99437.172  NaN            UPI0000138204  Q99437-1
#
#                        RefSeq         MANE APPRIS FLAGS               SIFT  \
# 0  NM_001297778.1;NM_022787.4  NM_022787.4  P1     NaN   tolerated(0.22)
# 1  NM_004958.4                 NM_004958.4  P1     NaN   deleterious(0)
# 2  NaN                         NaN          A2     NaN   deleterious(0.02)
# 3  NM_024503.5                 NM_024503.5  P5     NaN   tolerated(0.2)
# 4  NM_004047.5                 NM_004047.5  P1     NaN   tolerated(0.32)
#
#                    PolyPhen   EXON INTRON  \
# 0  benign(0.345)             2/5    NaN
# 1  probably_damaging(0.993)  52/58  NaN
# 2  probably_damaging(0.997)  19/24  NaN
# 3  benign(0.003)             8/9    NaN
# 4  benign(0.017)             3/8    NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    DOMAINS  \
# 0  PDB-ENSP_mappings:1gzu.A;PDB-ENSP_mappings:1gzu.B;PDB-ENSP_mappings:1gzu.C;PDB-ENSP_mappings:1kku.A;PDB-ENSP_mappings:1kqn.A;PDB-ENSP_mappings:1kqn.B;PDB-ENSP_mappings:1kqn.C;PDB-ENSP_mappings:1kqn.D;PDB-ENSP_mappings:1kqn.E;PDB-ENSP_mappings:1kqn.F;PDB-ENSP_mappings:1kqo.A;PDB-ENSP_mappings:1kqo.B;PDB-ENSP_mappings:1kqo.C;PDB-ENSP_mappings:1kqo.D;PDB-ENSP_mappings:1kqo.E;PDB-ENSP_mappings:1kqo.F;PDB-ENSP_mappings:1kr2.A;PDB-ENSP_mappings:1kr2.B;PDB-ENSP_mappings:1kr2.C;PDB-ENSP_mappings:1kr2.D;PDB-ENSP_mappings:1kr2.E;PDB-ENSP_mappings:1kr2.F;Pfam:PF01467;PANTHER:PTHR12039;PANTHER:PTHR12039:SF16;Superfamily:SSF52374;TIGRFAM:TIGR00482;CDD:cd09286
# 1  PDB-ENSP_mappings:3jbz.A;PDB-ENSP_mappings:4jsn.A;PDB-ENSP_mappings:4jsn.B;PDB-ENSP_mappings:4jsp.A;PDB-ENSP_mappings:4jsp.B;PDB-ENSP_mappings:4jsv.A;PDB-ENSP_mappings:4jsv.B;PDB-ENSP_mappings:4jsx.A;PDB-ENSP_mappings:4jsx.B;PDB-ENSP_mappings:4jt5.A;PDB-ENSP_mappings:4jt5.B;PDB-ENSP_mappings:4jt6.A;PDB-ENSP_mappings:4jt6.B;PDB-ENSP_mappings:5flc.B;PDB-ENSP_mappings:5flc.F;PDB-ENSP_mappings:5h64.A;PDB-ENSP_mappings:5h64.a;PDB-ENSP_mappings:5wbu.A;PDB-ENSP_mappings:5wbu.B;PDB-ENSP_mappings:5wby.A;PDB-ENSP_mappings:5wby.B;PDB-ENSP_mappings:5zcs.A;PDB-ENSP_mappings:5zcs.B;PDB-ENSP_mappings:6bcu.A;PDB-ENSP_mappings:6bcu.B;PDB-ENSP_mappings:6bcx.A;PDB-ENSP_mappings:6bcx.B;PDB-ENSP_mappings:6sb0.A;PDB-ENSP_mappings:6sb0.B;PDB-ENSP_mappings:6sb2.A;PDB-ENSP_mappings:6sb2.B;PROSITE_profiles:PS50290;CDD:cd05169;PANTHER:PTHR11139;PANTHER:PTHR11139:SF9;Gene3D:1.10.1070.11;Pfam:PF00454;SMART:SM00146;Superfamily:SSF56112
# 2  Gene3D:2.60.40.10;PANTHER:PTHR11200:SF163;PANTHER:PTHR11200
# 3  PANTHER:PTHR45944;PANTHER:PTHR45944:SF5;MobiDB_lite:mobidb-lite;MobiDB_lite:mobidb-lite
# 4  PANTHER:PTHR10263;PANTHER:PTHR10263:SF18
#
#    1000G_AF  1000G_AFR_AF  1000G_AMR_AF  1000G_EAS_AF  1000G_EUR_AF  \
# 0 NaN       NaN           NaN           NaN           NaN
# 1 NaN       NaN           NaN           NaN           NaN
# 2 NaN       NaN           NaN           NaN           NaN
# 3 NaN       NaN           NaN           NaN           NaN
# 4 NaN       NaN           NaN           NaN           NaN
#
#    1000G_SAS_AF  ESP_AA_AF  ESP_EA_AF  gnomAD_AF  gnomAD_AFR_AF  \
# 0 NaN           NaN        NaN        NaN        NaN
# 1 NaN           NaN        NaN        NaN        NaN
# 2 NaN           NaN        NaN        NaN        NaN
# 3 NaN           NaN        NaN         0.000016   0.0
# 4 NaN           NaN        NaN         0.000004   0.0
#
#    gnomAD_AMR_AF  gnomAD_ASJ_AF  gnomAD_EAS_AF  gnomAD_FIN_AF  gnomAD_NFE_AF  \
# 0 NaN            NaN            NaN            NaN            NaN
# 1 NaN            NaN            NaN            NaN            NaN
# 2 NaN            NaN            NaN            NaN            NaN
# 3  0.0            0.0            0.000054       0.0            0.000009
# 4  0.0            0.0            0.000000       0.0            0.000000
#
#    gnomAD_OTH_AF  gnomAD_SAS_AF    MAX_AF MAX_AF_POPS  gnomAD_non_cancer_AF  \
# 0 NaN            NaN            NaN        NaN        NaN
# 1 NaN            NaN            NaN        NaN        NaN
# 2 NaN            NaN            NaN        NaN         0.000007
# 3  0.0            0.000065       0.000065  gnomAD_SAS  0.000014
# 4  0.0            0.000033       0.000033  gnomAD_SAS NaN
#
#    gnomAD_non_cancer_AFR_AF  gnomAD_non_cancer_AMI_AF  \
# 0 NaN                       NaN
# 1 NaN                       NaN
# 2  0.0                       0.0
# 3  0.0                       0.0
# 4 NaN                       NaN
#
#    gnomAD_non_cancer_AMR_AF  gnomAD_non_cancer_ASJ_AF  \
# 0 NaN                       NaN
# 1 NaN                       NaN
# 2  0.0                       0.0
# 3  0.0                       0.0
# 4 NaN                       NaN
#
#    gnomAD_non_cancer_EAS_AF  gnomAD_non_cancer_FIN_AF  \
# 0 NaN                       NaN
# 1 NaN                       NaN
# 2  0.0                       0.0
# 3  0.0                       0.0
# 4 NaN                       NaN
#
#    gnomAD_non_cancer_MID_AF  gnomAD_non_cancer_NFE_AF  \
# 0 NaN                       NaN
# 1 NaN                       NaN
# 2  0.0                       0.000015
# 3  0.0                       0.000031
# 4 NaN                       NaN
#
#    gnomAD_non_cancer_OTH_AF  gnomAD_non_cancer_SAS_AF  \
# 0 NaN                       NaN
# 1 NaN                       NaN
# 2  0.0                       0.0
# 3  0.0                       0.0
# 4 NaN                       NaN
#
#    gnomAD_non_cancer_MAX_AF_adj gnomAD_non_cancer_MAX_AF_POPS_adj CLIN_SIG  \
# 0 NaN                            NaN                               NaN
# 1 NaN                            NaN                               NaN
# 2 NaN                            NaN                               NaN
# 3  0.000031                      nfe                               NaN
# 4 NaN                            NaN                               NaN
#
#   SOMATIC PUBMED  TRANSCRIPTION_FACTORS  MOTIF_NAME  MOTIF_POS  HIGH_INF_POS  \
# 0  1       NaN   NaN                    NaN         NaN        NaN
# 1  1;1     NaN   NaN                    NaN         NaN        NaN
# 2  1       NaN   NaN                    NaN         NaN        NaN
# 3  0;1     NaN   NaN                    NaN         NaN        NaN
# 4  0;1     NaN   NaN                    NaN         NaN        NaN
#
#    MOTIF_SCORE_CHANGE  miRNA    IMPACT  PICK VARIANT_CLASS  TSL  HGVS_OFFSET  \
# 0 NaN                 NaN     MODERATE  1.0   SNV           1.0 NaN
# 1 NaN                 NaN     MODERATE  1.0   SNV           1.0 NaN
# 2 NaN                 NaN     MODERATE  1.0   SNV           5.0 NaN
# 3 NaN                 NaN     MODERATE  1.0   SNV           1.0 NaN
# 4 NaN                 NaN     MODERATE NaN    SNV           1.0 NaN
#
#   PHENO  GENE_PHENO      CONTEXT                        tumor_bam_uuid  \
# 0  1     1.0         GAATGGAACAG  1806407b-9ebb-406e-aacc-56dd958c1316
# 1  1;1   1.0         CTTCTCTCGGG  1806407b-9ebb-406e-aacc-56dd958c1316
# 2  1    NaN          GTCCTCAATTT  1806407b-9ebb-406e-aacc-56dd958c1316
# 3  0;1  NaN          AGCATCGCTGG  1806407b-9ebb-406e-aacc-56dd958c1316
# 4  0;1  NaN          TGACGGAGACT  1806407b-9ebb-406e-aacc-56dd958c1316
#
#                         normal_bam_uuid                               case_id  \
# 0  f3c79c29-146e-490b-a55c-15c90f329dc8  ea645243-df49-4466-a255-9f3d4321e357
# 1  f3c79c29-146e-490b-a55c-15c90f329dc8  ea645243-df49-4466-a255-9f3d4321e357
# 2  f3c79c29-146e-490b-a55c-15c90f329dc8  ea645243-df49-4466-a255-9f3d4321e357
# 3  f3c79c29-146e-490b-a55c-15c90f329dc8  ea645243-df49-4466-a255-9f3d4321e357
# 4  f3c79c29-146e-490b-a55c-15c90f329dc8  ea645243-df49-4466-a255-9f3d4321e357
#
#   GDC_FILTER COSMIC hotspot RNA_Support  RNA_depth  RNA_ref_count  \
# 0  NaN        NaN    N       Unknown    NaN        NaN
# 1  NaN        NaN    N       Unknown    NaN        NaN
# 2  NaN        NaN    N       Unknown    NaN        NaN
# 3  NaN        NaN    N       Unknown    NaN        NaN
# 4  NaN        NaN    N       Unknown    NaN        NaN
#
#    RNA_alt_count                callers
# 0 NaN             muse;mutect2;varscan2
# 1 NaN             muse;mutect2;varscan2
# 2 NaN             muse;mutect2;varscan2
# 3 NaN             muse;mutect2;varscan2
# 4 NaN             muse;mutect2;varscan2

# %%
mutation_cut = mutation[(mutation['Hugo_Symbol']=='TP53') | (mutation['Hugo_Symbol'] == "BRCA1") | (mutation['Hugo_Symbol'] == 'BRCA2') | (mutation['Hugo_Symbol'] == 'MUC16')]

# %%
mutation_variant = mutation_cut.pivot_table(index='Hugo_Symbol', columns='Tumor_Sample_Barcode', values='Variant_Classification', aggfunc='first')

# %%
mutation_transpose = mutation_variant.transpose()

# %%
mutation_transpose.head()
# Out:
# Hugo_Symbol          BRCA1 BRCA2              MUC16               TP53
# Tumor_Sample_Barcode
# TCGA-3C-AALI          NaN   NaN   NaN                Nonsense_Mutation
# TCGA-5L-AAT0          NaN   NaN   Missense_Mutation  NaN
# TCGA-5L-AAT1          NaN   NaN   Missense_Mutation  NaN
# TCGA-5T-A9QA          NaN   NaN   Missense_Mutation  NaN
# TCGA-A1-A0SE          NaN   NaN   Missense_Mutation  NaN

# %%
count_gene = pd.merge(count, gene, left_on="Unnamed: 0", right_on="gene_id")

# %%
count_gene.head()
# Out:
#            Unnamed: 0  TCGA-LL-A73Y-01A-11R-A33J-07  \
# 0  ENSG00000000003.15  7015
# 2  4142                          1851
# 3  2945                          1662
# 4  779                           749
#
#    TCGA-D8-A1X9-01A-12R-A157-07  TCGA-A8-A08H-01A-21R-A00Z-07  \
# 0  1870                          1724
# 1  5                             46
# 2  4449                          1347
# 3  1942                          526
# 4  668                           429
#
#    TCGA-A1-A0SP-01A-11R-A084-07  TCGA-E2-A1LG-01A-21R-A14M-07  \
# 0  4246                          2514
# 1  6                             0
# 2  2498                          3064
# 3  791                           1562
# 4  917                           897
#
#    TCGA-B6-A0WV-01A-11R-A109-07  TCGA-AN-A049-01A-21R-A00Z-07  \
# 0  648                           1335
# 1  11                            65
# 2  2982                          1529
# 3  1223                          1281
# 4  517                           718
#
#    TCGA-OL-A6VO-01A-12R-A33J-07  TCGA-C8-A27B-01A-11R-A169-07  \
# 0  4489                          3345
# 1  6                             0
# 2  2053                          3178
# 3  914                           2311
# 4  1225                          3910
#
#    TCGA-AN-A0XP-01A-11R-A109-07  TCGA-BH-A0BV-01A-11R-A00Z-07  \
# 0  799                           463
# 1  0                             3
# 2  3319                          1820
# 3  2888                          1209
# 4  685                           517
#
#    TCGA-A7-A4SC-01A-12R-A266-07  TCGA-E2-A15T-01A-11R-A115-07  \
# 0  1377                          3456
# 1  9                             22
# 2  1127                          1779
# 3  1470                          2176
# 4  338                           864
#
#    TCGA-D8-A1XJ-01A-11R-A14M-07  TCGA-EW-A1OV-01A-11R-A144-07  \
# 0  3609                          2511
# 1  3                             9
# 2  5499                          1209
# 3  1046                          840
# 4  999                           408
#
#    TCGA-BH-A18V-01A-11R-A12D-07  TCGA-AC-A3BB-01A-21R-A19W-07  \
# 0  1091                          2249
# 1  24                            105
# 2  3559                          1580
# 3  1425                          1801
# 4  1967                          437
#
#    TCGA-AR-A24H-01A-11R-A169-07  TCGA-EW-A1OW-01A-21R-A144-07  \
# 0  2967                          4804
# 1  17                            102
# 2  5568                          1933
# 3  3458                          825
# 4  2060                          869
#
#    TCGA-BH-A0DV-01A-21R-A12P-07  TCGA-BH-A18G-01A-11R-A12D-07  \
# 0  3892                          2127
# 1  104                           0
# 2  1608                          742
# 3  1716                          911
# 4  554                           328
#
#    TCGA-AR-A1AU-01A-11R-A12P-07  TCGA-GM-A3XG-01A-31R-A24H-07  \
# 0  1537                          3791
# 1  94                            13
# 2  1499                          2323
# 3  1482                          1137
# 4  492                           255
#
#    TCGA-OL-A66O-01A-11R-A31O-07  TCGA-A7-A26F-01B-04R-A22O-07  \
# 0  2784                          981
# 1  6                             21
# 2  1886                          611
# 3  874                           1700
# 4  475                           753
#
#    TCGA-EW-A1P5-01A-11R-A144-07  TCGA-BH-A0C0-01A-21R-A056-07  \
# 0  807                           3092
# 1  1                             4
# 2  1753                          3044
# 3  592                           1284
# 4  344                           712
#
#    TCGA-GM-A2DB-01A-31R-A18M-07  TCGA-A1-A0SN-01A-11R-A144-07  \
# 0  5709                          837
# 1  3                             1
# 2  806                           5465
# 3  238                           1871
# 4  134                           844
#
#    TCGA-BH-A0B4-01A-11R-A00Z-07  TCGA-E2-A159-01A-11R-A115-07  \
# 0  1026                          3984
# 1  4                             6
# 2  1950                          3275
# 3  520                           1123
# 4  146                           1186
#
#    TCGA-BH-A0HU-01A-11R-A034-07  TCGA-C8-A1HE-01A-11R-A13Q-07  \
# 0  2127                          2540
# 1  32                            6
# 2  2564                          2814
# 3  1689                          4200
# 4  738                           1005
#
#    TCGA-D8-A1XG-01A-11R-A14D-07  TCGA-A7-A3RF-01A-11R-A22K-07  \
# 0  1539                          278
# 1  1                             0
# 2  1533                          1391
# 3  2179                          747
# 4  850                           154
#
#    TCGA-D8-A1JC-01A-11R-A13Q-07  TCGA-E2-A15G-01A-11R-A12D-07  \
# 0  3094                          1643
# 1  3                             13
# 2  4971                          1519
# 3  2999                          2278
# 4  1282                          614
#
#    TCGA-LL-A442-01A-11R-A24H-07  TCGA-D8-A1J9-01A-11R-A13Q-07  \
# 0  2116                          2275
# 1  9                             0
# 2  2506                          2973
# 3  1568                          4005
# 4  550                           1109
#
#    TCGA-E9-A5UP-01A-11R-A28M-07  TCGA-D8-A27N-01A-11R-A16F-07  \
# 0  3583                          1843
# 1  2                             49
# 2  2259                          2152
# 3  1827                          2295
# 4  346                           629
#
#    TCGA-BH-A0BP-01A-11R-A115-07  TCGA-E2-A158-01A-11R-A12D-07  \
# 0  944                           8037
# 1  361                           1
# 2  1851                          2814
# 3  2271                          1920
# 4  602                           795
#
#    TCGA-LD-A7W6-01A-81R-A352-07  TCGA-AC-A2B8-01A-11R-A17B-07  \
# 0  3688                          2932
# 1  81                            183
# 2  1635                          2023
# 3  1953                          2474
# 4  765                           1030
#
#    TCGA-AR-A1AR-01A-31R-A137-07  TCGA-E9-A1NE-01A-21R-A14M-07  \
# 0  3210                          1566
# 1  129                           73
# 2  2486                          4456
# 3  1823                          2215
# 4  3238                          1074
#
#    TCGA-BH-A0BJ-01A-11R-A056-07  TCGA-LL-A7SZ-01A-32R-A352-07  \
# 0  4546                          2234
# 1  97                            3
# 2  1574                          1288
# 3  2107                          372
# 4  796                           177
#
#    TCGA-S3-AA0Z-01A-11R-A41B-07  TCGA-AO-A0JE-01A-11R-A056-07  \
# 0  3517                          2202
# 1  2                             4
# 2  2268                          1857
# 3  2896                          1705
# 4  2357                          559
#
#    TCGA-A2-A25C-01A-11R-A169-07  TCGA-AR-A5QQ-01A-11R-A28M-07  \
# 0  3396                          1721
# 1  36                            5
# 2  3882                          2347
# 3  3756                          306
# 4  2407                          479
#
#    TCGA-D8-A1X6-01A-11R-A14M-07  TCGA-E9-A1R7-01A-11R-A14M-07  \
# 0  1307                          3490
# 1  9                             21
# 2  3256                          6760
# 3  2611                          3321
# 4  906                           1311
#
#    TCGA-D8-A1XD-01A-11R-A14D-07  TCGA-AR-A1AW-01A-21R-A12P-07  \
# 0  2823                          2273
# 1  0                             13
# 2  2777                          2077
# 3  1080                          1459
# 4  400                           726
#
#    TCGA-B6-A0RH-01A-21R-A115-07  TCGA-AC-A23H-01A-11R-A157-07  \
# 0  1970                          609
# 1  0                             0
# 2  2926                          3987
# 3  1822                          4116
# 1  16                            48
# 2  4127                          2776
# 3  3003                          1152
# 4  599                           968
#
#    TCGA-E9-A1N5-01A-11R-A14D-07  TCGA-OL-A66P-01A-11R-A31O-07  \
# 0  1027                          623
# 1  12                            11
# 2  1417                          1589
# 3  811                           364
# 4  367                           108
#
#    TCGA-A8-A093-01A-11R-A00Z-07  TCGA-E2-A10E-01A-21R-A10J-07  \
# 0  5302                          655
# 1  73                            41
# 2  1850                          2275
# 3  2473                          3068
# 4  1308                          800
#
#    TCGA-A8-A0AD-01A-11R-A056-07  TCGA-E2-A105-01A-11R-A10J-07  \
# 0  1682                          706
# 1  9                             12
# 2  1433                          4621
# 3  614                           1390
# 4  337                           702
#
#    TCGA-E9-A1R4-01A-21R-A14D-07  TCGA-5L-AAT0-01A-12R-A41B-07  \
# 0  711                           2878
# 1  15                            5
# 2  1943                          918
# 3  1285                          679
# 4  549                           242
#
#    TCGA-EW-A6SD-01A-12R-A33J-07  TCGA-E9-A1RG-01A-11R-A14D-07  \
# 0  2535                          629
# 1  1                             6
# 2  2610                          3189
# 3  1533                          828
# 4  502                           429
#
#    TCGA-BH-A6R8-01A-21R-A33J-07  TCGA-A8-A06Y-01A-21R-A00Z-07  \
# 0  1985                          7666
# 1  4                             0
# 2  3463                          2418
# 3  1631                          1464
# 4  412                           529
#
#    TCGA-C8-A1HF-01A-11R-A137-07  TCGA-A8-A0A6-01A-12R-A056-07  \
# 0  3292                          2452
# 1  2                             17
# 2  3639                          1619
# 3  1508                          2494
# 4  897                           534
#
#    TCGA-A2-A0EP-01A-52R-A22U-07  TCGA-D8-A3Z6-01A-11R-A239-07  \
# 0  2714                          1341
# 1  253                           0
# 2  1940                          1597
# 3  2960                          2516
# 4  552                           463
#
#    TCGA-A2-A3XW-01A-11R-A239-07  TCGA-AO-A0J8-01A-21R-A034-07  \
# 0  907                           3861
# 1  13                            33
# 2  1383                          2138
# 3  781                           3684
# 4  179                           1155
#
#    TCGA-BH-A0DL-01A-11R-A115-07  TCGA-E9-A1N9-01A-11R-A14D-07  \
# 0  4032                          2138
# 1  9                             12
# 2  2818                          1719
# 3  2360                          1375
# 4  1292                          594
#
#    TCGA-A2-A25D-01A-12R-A16F-07  TCGA-A7-A13D-01B-04R-A277-07  \
# 0  4474                          679
# 1  9                             31
# 2  1785                          781
# 3  1362                          673
# 4  433                           824
#
#    TCGA-AO-A03R-01A-21R-A034-07  TCGA-A7-A3J1-01A-11R-A213-07  \
# 0  1098                          4893
# 1  33                            198
# 2  974                           2063
# 3  896                           3486
# 4  471                           1011
#
#    TCGA-E2-A15D-01A-11R-A115-07  TCGA-AN-A03Y-01A-21R-A00Z-07  \
# 0  4243                          4702
# 1  85                            16
# 2  1590                          2876
# 3  3535                          1542
# 4  678                           1250
#
#    TCGA-E9-A1R3-01A-31R-A14M-07  TCGA-A7-A26I-01B-06R-A22O-07  \
# 0  2890                          404
# 1  4                             18
# 2  4025                          336
# 3  2769                          2061
# 4  663                           1925
#
#    TCGA-BH-A18Q-01A-12R-A12D-07  TCGA-AN-A0FN-01A-11R-A034-07  \
# 0  3600                          2443
# 1  77                            144
# 2  2078                          2322
# 3  2576                          1466
# 4  948                           409
#
#    TCGA-AO-A0J5-01A-11R-A034-07  TCGA-E2-A14Y-01A-21R-A12D-07  \
# 0  2182                          4324
# 1  41                            0
# 2  1276                          2559
# 3  2952                          649
# 4  578                           638
#
#    TCGA-PE-A5DC-01A-12R-A27Q-07  TCGA-AR-A251-01A-12R-A169-07  \
# 0  2343                          3071
# 1  5                             51
# 2  1509                          14779
# 3  863                           4127
# 4  537                           3720
#
#    TCGA-A8-A08X-01A-21R-A00Z-07  TCGA-A2-A04Y-01A-21R-A034-07  \
# 0  1554                          2626
# 1  0                             76
# 2  1837                          2454
# 3  819                           1403
# 4  585                           402
#
#    TCGA-E9-A5UO-01A-11R-A28M-07  TCGA-WT-AB44-01A-11R-A41B-07  \
# 0  1286                          716
# 1  5                             24
# 2  1437                          617
# 3  844                           769
# 4  484                           122
#
#    TCGA-LL-A73Z-01A-11R-A32P-07  TCGA-BH-A204-01A-11R-A157-07  \
# 0  2914                          937
# 1  50                            7
# 2  2148                          4074
# 3  748                           2014
# 4  502                           952
#
#    TCGA-LL-A6FR-01A-12R-A31O-07  TCGA-GM-A4E0-01A-12R-A266-07  \
# 0  2115                          1677
# 1  2                             470
# 2  2056                          881
# 3  633                           486
# 4  260                           139
#
#    TCGA-C8-A273-01A-11R-A16F-07  TCGA-AO-A124-01A-11R-A10J-07  \
# 0  1522                          3053
# 1  4                             35
# 2  7186                          2862
# 3  1863                          1502
# 4  688                           1941
#
#    TCGA-D8-A1J8-01A-11R-A13Q-07  TCGA-BH-A0BC-01A-22R-A084-07  \
# 0  1084                          1162
# 1  0                             90
# 2  4023                          1703
# 3  3704                          1401
# 4  2409                          876
#
#    TCGA-A2-A0EU-01A-22R-A056-07  TCGA-AO-A129-01A-21R-A10J-07  \
# 0  3621                          3180
# 1  0                             31
# 2  2506                          4134
# 3  1261                          989
# 4  500                           924
#
#    TCGA-C8-A3M7-01A-12R-A21T-07  TCGA-E9-A245-01A-22R-A16F-07  \
# 0  4580                          312
# 1  31                            11
# 2  3138                          994
# 3  3593                          863
# 4  721                           179
#
#    TCGA-BH-A8G0-01A-11R-A352-07  TCGA-A1-A0SB-01A-11R-A144-07  \
# 0  2399                          4148
# 1  16                            604
# 2  1283                          1194
# 3  1472                          996
# 4  285                           337
#
#    TCGA-E9-A3QA-01A-61R-A22K-07  TCGA-BH-A0HF-01A-11R-A056-07  \
# 0  2448                          5053
# 1  3                             27
# 2  2499                          1619
# 3  707                           1008
# 4  408                           346
#
#    TCGA-E2-A15H-01A-11R-A12D-07  TCGA-A7-A13D-01A-13R-A277-07  \
# 0  1374                          1850
# 1  6                             1
# 2  1656                          1957
# 3  1464                          731
# 4  535                           1019
#
#    TCGA-BH-A18V-06A-11R-A213-07  TCGA-AC-A7VB-01A-11R-A352-07  \
# 0  1160                          3958
# 1  17                            18
# 2  2809                          2113
# 3  1619                          1830
# 4  883                           931
#
# 0  4271                          83
# 1  92                            1
# 2  2343                          2163
# 3  3467                          626
# 4  2193                          491
#
#    TCGA-BH-A1ES-06A-12R-A24H-07  TCGA-AR-A2LM-01A-11R-A180-07  \
# 0  4187                          6395
# 1  1                             22
# 2  2148                          1770
# 3  1970                          2934
# 4  555                           853
#
#    TCGA-E2-A15R-01A-11R-A115-07  TCGA-D8-A27L-01A-11R-A16F-07  \
# 0  502                           5504
# 1  12                            13
# 2  3234                          2403
# 3  3899                          1974
# 4  1511                          692
#
#    TCGA-E9-A24A-01A-11R-A169-07  TCGA-EW-A1PA-01A-11R-A144-07  \
# 0  1290                          356
# 1  6                             18
# 2  2641                          4413
# 3  2622                          1016
# 4  769                           505
#
#    TCGA-E2-A15J-01A-11R-A12P-07  TCGA-A2-A0CT-01A-31R-A056-07  \
# 0  1220                          4901
# 1  1                             2
# 2  1644                          2691
# 3  2818                          2350
# 4  858                           791
#
#    TCGA-A7-A13G-01A-11R-A13Q-07  TCGA-GM-A2DC-01A-11R-A18M-07  \
# 0  3299                          1369
# 1  24                            5
# 2  1465                          1544
# 3  5199                          1607
# 4  1257                          228
#
#    TCGA-B6-A40C-01A-11R-A239-07  TCGA-A2-A04P-01A-31R-A034-07  \
# 0  1145                          3875
# 1  77                            5
# 2  2066                          870
# 3  2809                          649
# 4  1008                          257
#
#    TCGA-AN-A04A-01A-21R-A034-07  TCGA-A2-A0ST-01A-12R-A084-07  \
# 0  1417                          3345
# 1  9                             23
# 2  1982                          1792
# 3  1227                          955
# 4  284                           576
#
#    TCGA-E9-A3X8-01A-31R-A22U-07  TCGA-BH-A0H5-01A-21R-A115-07  \
# 0  2090                          1825
# 1  36                            63
# 2  1179                          1737
# 3  645                           1596
# 4  150                           483
#
#    TCGA-BH-A0B3-01A-11R-A056-07  TCGA-AN-A0FJ-01A-11R-A00Z-07  \
# 0  2480                          2300
# 1  11                            7
# 2  1845                          1418
# 3  949                           674
# 4  1024                          691
#
#    TCGA-GM-A2D9-01A-11R-A18M-07  TCGA-A8-A08I-01A-11R-A00Z-07  \
# 0  655                           6050
# 1  8                             7
# 2  757                           4092
# 3  1322                          2024
# 4  226                           1450
#
#    TCGA-BH-A1EW-01A-11R-A137-07  TCGA-A7-A0DC-01B-04R-A22O-07  \
# 0  2690                          519
# 1  27                            9
# 2  2435                          530
# 3  2226                          722
# 4  945                           246
#
#    TCGA-HN-A2NL-01A-11R-A18M-07  TCGA-C8-A26Z-01A-11R-A16F-07  \
# 0  5598                          2340
# 1  1                             3
# 2  3083                          2795
# 3  1446                          3023
# 4  1015                          889
#
#    TCGA-EW-A1IX-01A-12R-A144-07  TCGA-EW-A1PG-01A-11R-A144-07  \
# 0  1410                          2617
# 1  14                            7
# 2  1431                          1534
# 3  1556                          945
# 4  318                           275
#
#    TCGA-E2-A14R-01A-11R-A115-07  TCGA-E9-A6HE-01A-11R-A31O-07  \
# 0  1882                          2279
# 1  1                             53
# 2  3138                          1703
# 3  628                           761
# 4  455                           635
#
#    TCGA-A2-A0CK-01A-11R-A22K-07  TCGA-B6-A0RL-01A-11R-A084-07  \
# 0  5869                          1938
# 1  175                           0
# 2  1584                          3701
# 3  1461                          1695
# 4  463                           1169
#
#    TCGA-A2-A3XT-01A-11R-A22U-07  TCGA-D8-A1JK-01A-11R-A13Q-07  \
# 0  1286                          4728
# 1  23                            1
# 2  4211                          1826
# 3  1472                          695
# 4  1507                          456
#
#    TCGA-LL-A8F5-01A-11R-A36F-07  TCGA-D8-A1JM-01A-11R-A13Q-07  \
# 0  1553                          4951
# 1  0                             198
# 2  2452                          3646
# 3  522                           1556
# 4  448                           1679
#
#    TCGA-B6-A0RE-01A-11R-A056-07  TCGA-EW-A1P3-01A-11R-A144-07  \
# 0  5274                          1368
# 1  3                             36
# 2  3125                          1225
# 3  934                           1049
# 4  1471                          437
#
#    TCGA-A8-A07P-01A-11R-A00Z-07  TCGA-C8-A130-01A-31R-A115-07  \
# 0  1288                          4079
# 1  18                            25
# 2  2744                          2689
# 3  1616                          911
# 4  653                           714
#
#    TCGA-A2-A04T-01A-21R-A034-07  TCGA-B6-A2IU-01A-32R-A18M-07  \
# 0  4244                          567
# 1  713                           24
# 2  3291                          601
# 3  2372                          2045
# 4  1659                          547
#
#    TCGA-AR-A250-01A-31R-A169-07  TCGA-E9-A1QZ-01A-21R-A169-07  \
# 0  2116                          3036
# 1  4                             826
# 2  3173                          3426
# 3  2016                          2437
# 4  1041                          1167
#
#    TCGA-AC-A6NO-01A-12R-A33J-07  TCGA-S3-AA10-01A-21R-A41B-07  \
# 0  4472                          1633
# 1  7                             0
# 2  2172                          2379
# 3  2636                          392
# 4  899                           509
#
#    TCGA-GM-A3XL-01A-11R-A22U-07  TCGA-AR-A2LR-01A-12R-A18M-07  \
# 0  1795                          3906
# 1  5                             66
# 2  4397                          1789
# 3  1042                          909
# 4  1466                          636
#
#    TCGA-BH-A18M-01A-11R-A12D-07  TCGA-AR-A2LJ-01A-12R-A19W-07  \
# 0  1635                          2100
# 1  101                           95
# 2  1565                          1331
# 3  1183                          701
# 4  419                           371
#
#    TCGA-AO-A12H-01A-11R-A115-07  TCGA-E2-A155-01A-11R-A12D-07  \
# 0  3957                          3148
# 1  3                             12
# 2  1802                          2303
# 3  1032                          1860
# 4  263                           637
#
#    TCGA-BH-A0BW-01A-11R-A115-07  TCGA-B6-A0X1-01A-11R-A109-07  \
# 0  3211                          1053
# 1  1                             1
# 2  2144                          1449
# 3  1707                          618
# 4  522                           597
#
#    TCGA-AC-A3OD-01B-06R-A22O-07  TCGA-AC-A6IX-01A-12R-A32P-07  \
# 0  519                           4024
# 1  11                            414
# 2  368                           1813
# 3  734                           1863
# 4  313                           552
#
#    TCGA-E9-A1RB-01A-11R-A157-07  TCGA-A8-A07Z-01A-11R-A00Z-07  \
# 0  2364                          2343
# 1  4                             2
# 2  4439                          1699
# 3  2278                          1092
# 4  2145                          664
#
#    TCGA-A2-A0EY-01A-11R-A034-07  source  type  score  phase  \
# 0  1954                          HAVANA  gene NaN    NaN
# 1  16                            HAVANA  gene NaN    NaN
# 2  2123                          HAVANA  gene NaN    NaN
# 3  1802                          HAVANA  gene NaN    NaN
# 4  694                           HAVANA  gene NaN    NaN
#
#               gene_id       gene_type gene_name  level     hgnc_id  \
# 0  ENSG00000000003.15  protein_coding  TSPAN6    2      HGNC:11858
# 1  ENSG00000000005.6   protein_coding  TNMD      2      HGNC:17757
# 2  ENSG00000000419.13  protein_coding  DPM1      2      HGNC:3005
# 3  ENSG00000000457.14  protein_coding  SCYL3     2      HGNC:19285
# 4  ENSG00000000460.17  protein_coding  C1orf112  2      HGNC:25565
#
#             havana_gene
# 0  OTTHUMG00000022002.2
# 1  OTTHUMG00000022001.2
# 2  OTTHUMG00000032742.2
# 3  OTTHUMG00000035941.6
# 4  OTTHUMG00000035821.9

# %%
specific_genes = count_gene[(count_gene['gene_name']=='TP53') | (count_gene['gene_name'] == "BRCA1") | (count_gene['gene_name'] == 'BRCA2') | (count_gene['gene_name'] == 'MUC16')]

# %%
specific_genes = specific_genes.transpose()
gene_names = specific_genes.loc['gene_name']
specific_genes.columns = gene_names.values.tolist()

# %%
specific_genes.head()
specific_genes = specific_genes.reset_index()

# %%
specific_genes.head()
# Out:
#                           index               BRCA1               BRCA2  \
# 0  Unnamed: 0                    ENSG00000012048.23  ENSG00000139618.16
# 1  TCGA-LL-A73Y-01A-11R-A33J-07  658                 646
# 2  TCGA-E2-A1IU-01A-11R-A14D-07  1104                529
# 3  TCGA-AO-A03U-01B-21R-A10J-07  735                 498
# 4  TCGA-E9-A1NH-01A-11R-A14D-07  321                 253
#
#                  TP53               MUC16
# 0  ENSG00000141510.18  ENSG00000181143.15
# 1  1809                4243
# 2  3233                703
# 3  4557                1239
# 4  5357                194

# %%
# mutation_transpose = mutation_transpose.reset_index()
mutation_transpose.head()
# Out:
# Hugo_Symbol                  BRCA1 BRCA2              MUC16               TP53
# Matched_Norm_Sample_Barcode
# TCGA-3C-AALI-10A-01D-A41F-09  NaN   NaN   NaN                Nonsense_Mutation
# TCGA-5L-AAT0-10A-01D-A41F-09  NaN   NaN   Missense_Mutation  NaN
# TCGA-5L-AAT1-10A-01D-A41F-09  NaN   NaN   Missense_Mutation  NaN
# TCGA-5T-A9QA-10A-01D-A41F-09  NaN   NaN   Missense_Mutation  NaN
# TCGA-A1-A0SE-10A-03D-A099-09  NaN   NaN   Missense_Mutation  NaN

# %%
merge_clinical = pd.merge(clinical, rna_clinical, left_on='Tumor_Sample_Barcode', right_on='patient')

# %%
merge_clinical = merge_clinical[['barcode',"Tumor_Sample_Barcode",  "breast_carcinoma_progesterone_receptor_status"]]

# %%
merge_clinical.head()
# Out:
#                         barcode Tumor_Sample_Barcode  \
# 0  TCGA-3C-AAAU-01A-11R-A41B-07  TCGA-3C-AAAU
# 1  TCGA-3C-AALI-01A-11R-A41B-07  TCGA-3C-AALI
# 2  TCGA-3C-AALJ-01A-31R-A41B-07  TCGA-3C-AALJ
# 3  TCGA-3C-AALK-01A-11R-A41B-07  TCGA-3C-AALK
# 4  TCGA-4H-AAAK-01A-12R-A41B-07  TCGA-4H-AAAK
#
#   breast_carcinoma_progesterone_receptor_status
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
all_merge = pd.merge(specific_genes, merge_clinical, left_on="index", right_on="barcode")

# %%
all_merge = pd.merge(all_merge, mutation_transpose, left_on='Tumor_Sample_Barcode', right_on="Tumor_Sample_Barcode")

# %%
all_merge = all_merge.set_index('barcode')
all_merge = all_merge.drop('index', axis=1)
all_merge = all_merge.drop('barcode', axis=1)

# %%
all_merge.head()
# Out:
#                              BRCA1_x BRCA2_x TP53_x MUC16_x  \
# barcode
# TCGA-LL-A73Y-01A-11R-A33J-07  658     646     1809   4243
# TCGA-BH-A1EY-01A-11R-A13Q-07  434     451     3218   10
# TCGA-B6-A0I6-01A-11R-A034-07  46      1117    1060   2203
# TCGA-D8-A27H-01A-11R-A16F-07  130     819     1373   47515
# TCGA-E2-A1II-01A-11R-A144-07  1101    609     5283   63
#
#                              Tumor_Sample_Barcode  \
# barcode
# TCGA-LL-A73Y-01A-11R-A33J-07  TCGA-LL-A73Y
# TCGA-BH-A1EY-01A-11R-A13Q-07  TCGA-BH-A1EY
# TCGA-B6-A0I6-01A-11R-A034-07  TCGA-B6-A0I6
# TCGA-D8-A27H-01A-11R-A16F-07  TCGA-D8-A27H
# TCGA-E2-A1II-01A-11R-A144-07  TCGA-E2-A1II
#
#                              breast_carcinoma_progesterone_receptor_status  \
# barcode
# TCGA-LL-A73Y-01A-11R-A33J-07  Negative
# TCGA-BH-A1EY-01A-11R-A13Q-07  Positive
# TCGA-B6-A0I6-01A-11R-A034-07  Negative
# TCGA-D8-A27H-01A-11R-A16F-07  Negative
# TCGA-E2-A1II-01A-11R-A144-07  Positive
#
#                              BRCA1_y            BRCA2_y            MUC16_y  \
# barcode
# TCGA-LL-A73Y-01A-11R-A33J-07  NaN     Missense_Mutation  NaN
# TCGA-BH-A1EY-01A-11R-A13Q-07  NaN     NaN                NaN
# TCGA-B6-A0I6-01A-11R-A034-07  NaN     NaN                NaN
# TCGA-D8-A27H-01A-11R-A16F-07  NaN     NaN                Missense_Mutation
# TCGA-E2-A1II-01A-11R-A144-07  NaN     NaN                NaN
#
#                                          TP53_y
# barcode
# TCGA-LL-A73Y-01A-11R-A33J-07  Splice_Site
# TCGA-BH-A1EY-01A-11R-A13Q-07  Missense_Mutation
# TCGA-B6-A0I6-01A-11R-A034-07  Frame_Shift_Del
# TCGA-D8-A27H-01A-11R-A16F-07  NaN
# TCGA-E2-A1II-01A-11R-A144-07  Splice_Site

# %%
from sklearn.neighbors import KNeighborsClassifier # default number of neighbors looked at is 5
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
target = all_merge.iloc[:, 4]
data = all_merge.drop(columns="breast_carcinoma_progesterone_receptor_status")

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
classifier = GaussianNB()
X_train, X_test, y_train, y_test = train_test_split(data, target, train_size=0.7)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
fraction_correct = sum(y_pred==y_test)/len(y_test)

# %%
print(fraction_correct)
# Out:
# 0.7159420289855073
